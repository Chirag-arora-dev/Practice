# %%
import numpy as np
import pandas as pd 
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Will upload data and print header of the data
samp = pd.read_csv("heart.csv")
samp.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
#Checking the tail(end) of the data
samp.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0  ...      0      0.0      1   1     2       0
#
# [5 rows x 14 columns]

# %%
#Checking description of the data
samp.describe()
# Out:
#               age         sex          cp  ...          ca        thal      target
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
#Checking datatypes in the dataset
samp.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
#Creating a sample empty plot
plt.plot();

# %%
#Using dummy values to describe working
#Addding semicolon at the end of plot command helps remove metadata 
x = np.array([9.6,7.8,5.4,3.2,1.1])
y = np.array([7.7,5.9,3.2,9.9,2.2])
plt.plot(x,y);

# %%
#Using pyplot api to build graphs
#However matplotlib's object oriented api is more flexible,
#And that should be preferred
#Creating a plot
fig = plt.figure()
ax = fig.add_subplot()
plt.show();

# %%
#Recommended method 
a = np.array([9,19,23,45,78])
b = np.array([87,98,56,43,32])
fig = plt.figure()
#adding data
ax = fig.add_axes()
plt.bar(a,b)
plt.suptitle("simple plot",fontsize=30)
plt.xlabel("x-axis",fontsize= 10)
plt.ylabel("y-axis",fontsize= 10)
plt.show()

# %%
#Making figures with numpy arrays
h = np.linspace(30,45,100)
fig,ax = plt.subplots()
ax.plot(h,h**2);

# %%
#Creating a scatter plot
fig,ax = plt.subplots()
ax.scatter(h,np.exp(h));

# %%
#Creating a bar graph
fig,ax = plt.subplots()
ax.bar(h,np.sin(h))
ax.set(title="Demo Bar Graph",
       ylabel="Y Axis");

# %%
#Histogram and Subplots
samp.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
s = np.random.randn(700)
fig,ax = plt.subplots()
ax.hist(s);

# %%
#Creating subplots in a diff way (Method 1)
#internet reference
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x, y)
axs[0, 0].set_title('Axis [0,0]')
axs[0, 1].plot(x, y, 'tab:orange')
axs[0, 1].set_title('Axis [0,1]')
axs[1, 0].plot(x, -y, 'tab:green')
axs[1, 0].set_title('Axis [1,0]')
axs[1, 1].plot(x, -y, 'tab:red')
axs[1, 1].set_title('Axis [1,1]')

for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %%
#Option 2 for plotting
#internet reference
fig, axes = plt.subplots(1, 3, figsize=(10, 4))

x = np.arange(0, 5, 0.25)

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %%
samp
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0     63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1     37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2     41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3     56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4     57    0   0       120   354    0  ...      1      0.6      2   0     2       1
# ..   ...  ...  ..       ...   ...  ...  ...    ...      ...    ...  ..   ...     ...
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# ...

# %%
#plotting from pandas dataframe
ts = pd.Series(np.random.randn(303))
index = pd.date_range("1/1/2020",periods = 303)
ts = ts.cumsum()
ts.plot();

# %%
samp.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
samp.plot(kind='scatter',
          x='age',
          y='chol',
          c='target');

# %%
#Using the matplotlib method
fig,ax = plt.subplots()
samp.plot(kind='scatter',
          x='age',
          y='chol',
          c='target',
          ax = ax);

# %%
#changing length of x axis and y axis
fig,ax = plt.subplots()
samp.plot(kind='scatter',
          x='age',
          y='chol',
          c='target',
          ax = ax);
ax.set_xlim([45,100]);
ax.set_ylim([200,600]);

# %%
#using legend with matplotlib graphs
v = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(v, np.sin(v), '-b', label='Sine')
ax.plot(v, np.cos(v), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend();

# %%
samp.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
#creating subplot of trestbps and thalach
fig,(ax0,ax1) = plt.subplots(2,1)
fig.suptitle("trestbps vs thalach and beats per second vs max heart rate",fontsize=20,fontweight="bold")
#customizing ax0
scatter = ax0.scatter(samp['trestbps'],
                      samp['thalach'],
                      color='cyan');
#customizing ax1
scatter = ax1.scatter(samp['age'],
              samp['chol'],
              color='green');

# %%
#to check diff types of  styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")
samp['trestbps'].plot();

# %%
#using another style
plt.style.use("ggplot")
samp['trestbps'].plot();

# %%
#rechanging the style
plt.style.use("dark_background")
samp['trestbps'].plot();

# %%
#new style
plt.style.use("bmh")
samp['trestbps'].plot();

# %%
#second last one
plt.style.use("seaborn-muted")
samp['trestbps'].plot();

# %%
#last style 
plt.style.use("seaborn-notebook")
samp['trestbps'].plot();

# %%
#ending it on a light note :-)
plt.style.use("seaborn-ticks")
samp['trestbps'].plot();

# %%
#Final step is saving plots
#One step is to do right click and download
#To do it through code write the following code
fig.savefig("practice.png")
